# %%
import sys
sys.path.append("../tsumugi/proto/")

# %%
from pyspark.sql import SparkSession
import pandas as pd

# %%
spark = SparkSession.builder.remote("sc://localhost:15002").getOrCreate()

# %%
test_data = spark.createDataFrame(
    [
        ["foo", 1, 4],
        ["bar", 2, 6],
        ["baz", 3, None],
    ],
    schema="struct<a:string, b:int, c:int>"
)

# %%
test_data.show()
# Out:
# +---+---+----+
# |  a|  b|   c|
# +---+---+----+
# |foo|  1|   4|
# |bar|  2|   6|
# |baz|  3|NULL|
# +---+---+----+

# %%
from tsumugi.verification import VerificationSuite
from tsumugi.analyzers import Size, Minimum, Completeness, CustomSql, ConstraintBuilder
from tsumugi.checks import CheckBuilder

# %%
suite = (
    VerificationSuite
    .on_data(test_data) # add DataFrame
    .with_row_level_results() # mark that row-level results are required
    .add_check(
        CheckBuilder()
        .with_description("Basic checks")
        .has_size(expected_size=3.0, name="Size(*)")
        .is_primary_key(column="b", name="col(b) should be PK-like")
        .build()
    )
    .add_check(
        CheckBuilder()
        .with_description("Additional checks")
        .is_complete(column="c", name="col(c) should be complete")
        .with_constraint(
            ConstraintBuilder()
            .for_analyzer(Minimum(column="b"))
            .should_be_eq_to(0.0)
            .build()
        )
        .build()
    )
)

# %%
result = suite.run_with_spark_session(spark)

# %%
from dataclasses import asdict

# %%
pd.DataFrame.from_records([asdict(dt) for dt in result.check_results])
# Out:
#      level  check_description  \
# 0  Warning       Basic checks
# 1  Warning       Basic checks
# 2  Warning       Basic checks
# 3  Warning  Additional checks
# 4  Warning  Additional checks
#
#                                   constraint_message   metric_name  \
# 0  Value: 3 does not meet the constraint requirem...          Size
# 1                                                       Uniqueness
# 2                                                     Completeness
# 3  Value: 0.6666666666666666 does not meet the co...  Completeness
# 4  Value: 1.0 does not meet the constraint requir...       Minimum
#
#   metric_instance metric_entity  metric_value   status  \
# 0               *       Dataset      3.000000  Failure
# 1               b        Column      1.000000  Success
# 2               b        Column      1.000000  Success
# 3               c        Column      0.666667  Failure
# 4               b        Column      1.000000  Failure
#
#                                           constraint
# 0                         SizeConstraint(Size(None))
# 1  UniquenessConstraint(Uniqueness(Buffer(b),None...
# 2  CompletenessConstraint(Completeness(b,None,Som...
# 3  CompletenessConstraint(Completeness(c,None,Som...
# 4  MinimumConstraint(Minimum(b,None,Some(Analyzer...

# %%
pd.DataFrame.from_records([asdict(dt) for dt in result.checks])
# Out:
#                check check_level check_status  \
# 0       Basic checks     Warning      Warning
# 1       Basic checks     Warning      Warning
# 2       Basic checks     Warning      Warning
# 3  Additional checks     Warning      Warning
# 4  Additional checks     Warning      Warning
#
#                                           constraint constraint_status  \
# 0                         SizeConstraint(Size(None))           Failure
# 1  UniquenessConstraint(Uniqueness(Buffer(b),None...           Success
# 2  CompletenessConstraint(Completeness(b,None,Som...           Success
# 3  CompletenessConstraint(Completeness(c,None,Som...           Failure
# 4  MinimumConstraint(Minimum(b,None,Some(Analyzer...           Failure
#
#                                   constraint_message
# 0  Value: 3 does not meet the constraint requirem...
# 1
# 2
# 3  Value: 0.6666666666666666 does not meet the co...
# 4  Value: 1.0 does not meet the constraint requir...

# %%
pd.DataFrame.from_records([asdict(dt) for dt in result.metrics])
# Out:
#     entity instance          name     value
# 0   Column        c  Completeness  0.666667
# 1   Column        b    Uniqueness  1.000000
# 2  Dataset        *          Size  3.000000
# 3   Column        b  Completeness  1.000000
# 4   Column        b       Minimum  1.000000

# %%
result.row_level_results.toPandas()
# Out:
#      a  b    c  Basic checks  Additional checks
# 0  foo  1  4.0          True              False
# 1  bar  2  6.0          True              False
# 2  baz  3  NaN          True              False
